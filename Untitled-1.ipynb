# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("weatherHistoryFormatted.csv")
dataset.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                     251          15.8263               1015.13
# 1                     259          15.8263               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
dataset.describe() #Exploring the dataset
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# count       96453.000000            96453.000000     96453.000000
# mean           10.810640              187.509232        10.347325
# std             6.913571              107.383428         4.192123
# min             0.000000                0.000000         0.000000
# ...

# %%
dataset.drop(["Precip Type","Temperature (C)","Wind Speed (km/h)","Wind Bearing (degrees)","Visibility (km)","Pressure (millibars)","Summary","Daily Summary"], axis =1,inplace=True)

# %%
dataset
# Out:
#                       Formatted Date  Apparent Temperature (C)  Humidity
# 0      2006-04-01 00:00:00.000 +0200                  7.388889      0.89
# 1      2006-04-01 01:00:00.000 +0200                  7.227778      0.86
# 2      2006-04-01 02:00:00.000 +0200                  9.377778      0.89
# 3      2006-04-01 03:00:00.000 +0200                  5.944444      0.83
# 4      2006-04-01 04:00:00.000 +0200                  6.977778      0.83
# ...                              ...                       ...       ...
# 96448  2016-09-09 19:00:00.000 +0200                 26.016667      0.43
# 96449  2016-09-09 20:00:00.000 +0200                 24.583333      0.48
# 96450  2016-09-09 21:00:00.000 +0200                 22.038889      0.56
# 96451  2016-09-09 22:00:00.000 +0200                 21.522222      0.60
# 96452  2016-09-09 23:00:00.000 +0200                 20.438889      0.61
#
# [96453 rows x 3 columns]

# %%
dataset["Formatted Date"] = pd.to_datetime(dataset["Formatted Date"], errors="coerce",utc=True)
dataset = dataset.set_index("Formatted Date")

# %%
dataset
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2006-03-31 22:00:00+00:00                  7.388889      0.89
# 2006-03-31 23:00:00+00:00                  7.227778      0.86
# 2006-04-01 00:00:00+00:00                  9.377778      0.89
# 2006-04-01 01:00:00+00:00                  5.944444      0.83
# 2006-04-01 02:00:00+00:00                  6.977778      0.83
# ...                                             ...       ...
# 2016-09-09 17:00:00+00:00                 26.016667      0.43
# 2016-09-09 18:00:00+00:00                 24.583333      0.48
# 2016-09-09 19:00:00+00:00                 22.038889      0.56
# 2016-09-09 20:00:00+00:00                 21.522222      0.60
# 2016-09-09 21:00:00+00:00                 20.438889      0.61
#
# [96453 rows x 2 columns]

# %%
dataset_mean = dataset[["Apparent Temperature (C)", "Humidity"]].resample("MS").mean()

# %%
dataset_mean
# Out:
#                            Apparent Temperature (C)  Humidity
# Formatted Date
# 2005-12-01 00:00:00+00:00                 -4.050000  0.890000
# 2006-01-01 00:00:00+00:00                 -4.173708  0.834610
# 2006-02-01 00:00:00+00:00                 -2.990716  0.843467
# 2006-03-01 00:00:00+00:00                  1.969780  0.778737
# 2006-04-01 00:00:00+00:00                 12.098827  0.728625
# ...                                             ...       ...
# 2016-08-01 00:00:00+00:00                 21.383094  0.674046
# 2016-09-01 00:00:00+00:00                 18.355833  0.688833
# 2016-10-01 00:00:00+00:00                  8.923947  0.799906
# 2016-11-01 00:00:00+00:00                  3.048627  0.848472
# 2016-12-01 00:00:00+00:00                 -2.017272  0.887981
#
# [133 rows x 2 columns]

# %%
plt.figure(figsize=(7,5))
plt.plot(dataset_mean)
plt.ylabel("Mean_Value",size=12)
plt.xlabel("No. of Years",size=12)
plt.title("Variation in AT and Humidity",size=17)
plt.legend(dataset_mean,loc="upper right")
plt.show()

# %%
January = dataset[dataset.index.month ==1]
plt.figure(figsize=(7,5))
plt.plot(January.loc["2006-01-01":"2016-01-01","Apparent Temperature (C)"],marker ="o", linestyle ="-", label ="Apparent Temperature")
plt.plot(January.loc["2006-01-01":"2016-01-01","Humidity"],marker ="o", linestyle ="-", label ="Humidity")
plt.legend(loc = "upper right", fontsize = 7)
plt.xlabel("Month of January", fontsize = 15)
plt.title("Humidity vs Apparent Temperature", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Humidity vs Apparent Temperature')

# %%
February = dataset[dataset.index.month ==2]
plt.figure(figsize=(7,5))
plt.plot(February.loc["2006-02-01":"2016-02-01","Apparent Temperature (C)"],marker ="o", linestyle ="-", label ="Apparent Temperature")
plt.plot(February.loc["2006-02-01":"2016-02-01","Humidity"],marker ="o", linestyle ="-", label ="Humidity")
plt.legend(loc = "center right", fontsize = 7)
plt.xlabel("Month of February", fontsize = 15)
plt.title("Humidity vs Apparent Temperature", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Humidity vs Apparent Temperature')

# %%
March = dataset[dataset.index.month ==3]
plt.figure(figsize=(7,5))
plt.plot(March.loc["2006-03-01":"2016-03-01","Apparent Temperature (C)"],marker ="o", linestyle ="-", label ="Apparent Temperature")
plt.plot(March.loc["2006-03-01":"2016-03-01","Humidity"],marker ="o", linestyle ="-", label ="Humidity")
plt.legend(loc = "lower right", fontsize = 7)
plt.xlabel("Month of March", fontsize = 15)
plt.title("Humidity vs Apparent Temperature", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Humidity vs Apparent Temperature')

# %%
April = dataset[dataset.index.month ==4]
plt.figure(figsize=(7,5))
plt.plot(April.loc["2006-04-01":"2016-04-01","Apparent Temperature (C)"],marker ="o", linestyle ="-", label ="Apparent Temperature")
plt.plot(April.loc["2006-04-01":"2016-04-01","Humidity"],marker ="o", linestyle ="-", label ="Humidity")
plt.legend(loc = "upper right", fontsize = 7)
plt.xlabel("Month of April", fontsize = 15)
plt.title("Humidity vs Apparent Temperature", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Humidity vs Apparent Temperature')

# %%
May = dataset[dataset.index.month ==5]
plt.figure(figsize=(7,5))
plt.plot(May.loc["2006-05-01":"2016-05-01","Apparent Temperature (C)"],marker ="o", linestyle ="-", label ="Apparent Temperature")
plt.plot(May.loc["2006-05-01":"2016-05-01","Humidity"],marker ="o", linestyle ="-", label ="Humidity")
plt.legend(loc = "upper right", fontsize = 7)
plt.xlabel("Month of May", fontsize = 15)
plt.title("Humidity vs Apparent Temperature", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Humidity vs Apparent Temperature')

# %%
June = dataset[dataset.index.month ==6]
plt.figure(figsize=(7,5))
plt.plot(June.loc["2006-06-01":"2016-06-01","Apparent Temperature (C)"],marker ="o", linestyle ="-", label ="Apparent Temperature")
plt.plot(June.loc["2006-06-01":"2016-06-01","Humidity"],marker ="o", linestyle ="-", label ="Humidity")
plt.legend(loc = "upper right", fontsize = 7)
plt.xlabel("Month of June", fontsize = 16)
plt.title("Humidity vs Apparent Temperature", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Humidity vs Apparent Temperature')

# %%
July = dataset[dataset.index.month ==7]
plt.figure(figsize=(7,5))
plt.plot(July.loc["2006-07-01":"2016-07-01","Apparent Temperature (C)"],marker ="o", linestyle ="-", label ="Apparent Temperature")
plt.plot(July.loc["2006-07-01":"2016-07-01","Humidity"],marker ="o", linestyle ="-", label ="Humidity")
plt.legend(loc = "upper right", fontsize = 7)
plt.xlabel("Month of July", fontsize = 17)
plt.title("Humidity vs Apparent Temperature", fontsize=17)
# Out:
# Text(0.5, 1.0, 'Humidity vs Apparent Temperature')

# %%
August = dataset[dataset.index.month ==8]
plt.figure(figsize=(7,5))
plt.plot(August.loc["2006-08-01":"2016-08-01","Apparent Temperature (C)"],marker ="o", linestyle ="-", label ="Apparent Temperature")
plt.plot(August.loc["2006-08-01":"2016-08-01","Humidity"],marker ="o", linestyle ="-", label ="Humidity")
plt.legend(loc = "upper right", fontsize = 7)
plt.xlabel("Month of August", fontsize = 17)
plt.title("Humidity vs Apparent Temperature", fontsize=17)
# Out:
# Text(0.5, 1.0, 'Humidity vs Apparent Temperature')

# %%
September = dataset[dataset.index.month ==9]
plt.figure(figsize=(7,5))
plt.plot(September.loc["2006-09-01":"2016-09-01","Apparent Temperature (C)"],marker ="o", linestyle ="-", label ="Apparent Temperature")
plt.plot(September.loc["2006-09-01":"2016-09-01","Humidity"],marker ="o", linestyle ="-", label ="Humidity")
plt.legend(loc = "upper right", fontsize = 7)
plt.xlabel("Month of September", fontsize = 17)
plt.title("Humidity vs Apparent Temperature", fontsize=17)
# Out:
# Text(0.5, 1.0, 'Humidity vs Apparent Temperature')

# %%
October = dataset[dataset.index.month ==10]
plt.figure(figsize=(7,5))
plt.plot(October.loc["2006-10-01":"2016-10-01","Apparent Temperature (C)"],marker =".", linestyle ="-", label ="Apparent Temperature")
plt.plot(October.loc["2006-10-01":"2016-10-01","Humidity"],marker =".", linestyle ="-", label ="Humidity")
plt.legend(loc = "upper right", fontsize = 7)
plt.xlabel("Month of October", fontsize = 17)
plt.title("Humidity vs Apparent Temperature", fontsize=17)
# Out:
# Text(0.5, 1.0, 'Humidity vs Apparent Temperature')

# %%
November = dataset[dataset.index.month ==11]
plt.figure(figsize=(7,5))
plt.plot(November.loc["2006-11-01":"2016-11-01","Apparent Temperature (C)"],marker =".", linestyle ="-", label ="Apparent Temperature")
plt.plot(November.loc["2006-11-01":"2016-11-01","Humidity"],marker =".", linestyle ="-", label ="Humidity")
plt.legend(loc = "upper right", fontsize = 7)
plt.xlabel("Month of November", fontsize = 17)
plt.title("Humidity vs Apparent Temperature", fontsize=17)
# Out:
# Text(0.5, 1.0, 'Humidity vs Apparent Temperature')

# %%
December = dataset[dataset.index.month ==12]
plt.figure(figsize=(7,5))
plt.plot(December.loc["2006-12-01":"2016-12-01","Apparent Temperature (C)"],marker =".", linestyle ="-", label ="Apparent Temperature")
plt.plot(December.loc["2006-12-01":"2016-12-01","Humidity"],marker =".", linestyle ="-", label ="Humidity")
plt.legend(loc = "upper right", fontsize = 7)
plt.xlabel("Month of December", fontsize = 17)
plt.title("Humidity vs Apparent Temperature", fontsize=17)
# Out:
# Text(0.5, 1.0, 'Humidity vs Apparent Temperature')
